# %%
import pandas as pd

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.columns  = ['bike_name', 'price', 'city', 'driven', 'owner', 'bike_age', 'power','brand']

# %%
df
# Out:
#                                   bike_name     price       city   driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad  17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi  11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi    110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore  16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore  10000.0
# ...                                     ...       ...        ...      ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi  22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal   6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi  20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur  84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune  60857.0
#
#              owner  bike_age  power          brand
# ...

# %%
df.dtypes
# Out:
# bike_name     object
# price        float64
# city          object
# driven       float64
# owner         object
# bike_age     float64
# power        float64
# brand         object
# dtype: object

# %%
df['price'] = df['price'].astype('int')

# %%
df['price'].dtypes
# Out:
# dtype('int32')

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
dict1 = {'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4}
dict1
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner'] = df['owner'].map(dict1)

# %%
df['owner']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 32643    1
# 32644    1
# 32645    1
# 32646    1
# 32647    1
# Name: owner, Length: 32648, dtype: int64

# %%
df['owner']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 32643    1
# 32644    1
# 32645    1
# 32646    1
# 32647    1
# Name: owner, Length: 32648, dtype: int64

# %%
df['price_five']  = df['price']+5

# %%
df['price+owner']  =  df['price']  +  df['owner']

# %%
df
# Out:
#                                   bike_name   price       city   driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad  17654.0
# 1               Royal Enfield Classic 350cc  119900      Delhi  11000.0
# 2                      Triumph Daytona 675R  600000      Delhi    110.0
# 3                      TVS Apache RTR 180cc   65000  Bangalore  16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore  10000.0
# ...                                     ...     ...        ...      ...
# 32643                Hero Passion Pro 100cc   39000      Delhi  22000.0
# 32644                  TVS Apache RTR 180cc   30000     Karnal   6639.0
# 32645              Bajaj Avenger Street 220   60000      Delhi  20373.0
# 32646             Hero Super Splendor 125cc   15600     Jaipur  84186.0
# 32647                    Bajaj Pulsar 150cc   22000       Pune  60857.0
#
#        owner  bike_age  power          brand  price_five  price+owner
# ...

# %%
df = pd.read_csv('Used_Bikes.csv')

# %%
group  =  df.groupby('owner')

# %%
group

# %%
group[['price']].mean()
# Out:
#                              price
# owner
# First Owner           69512.420037
# Fourth Owner Or More  61332.500000
# Second Owner          53552.263651
# Third Owner           81431.916667

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
group[['price','kms_driven']].min()
# Out:
#                         price  kms_driven
# owner
# First Owner            4400.0         3.0
# Fourth Owner Or More  11000.0      2009.0
# Second Owner           7500.0         1.0
# Third Owner            7000.0        23.0

# %%
df['price'].mean()
# Out:
# 68295.41763660868

# %%
df[df['owner'] == 'Fourth Owner Or More']['price'].mean()
# Out:
# 61332.5

# %%
group.agg({'price':'mean','kms_driven':'mean','power':'max'})
# Out:
#                              price    kms_driven   power
# owner
# First Owner           69512.420037  26474.521793  1800.0
# Fourth Owner Or More  61332.500000  29173.333333   350.0
# Second Owner          53552.263651  24465.370125  1200.0
# Third Owner           81431.916667  34606.138889   800.0

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
import numpy

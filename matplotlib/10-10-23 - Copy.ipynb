# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pip install matplotlib

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
plt.plot(df['total_bill'])

# %%
plt.plot(df['total_bill'])
plt.title('line plot')
plt.show()

# %%
dinner = df[df['time'] == 'Dinner']
dinner
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
dinner['time'].value_counts()
# Out:
# time
# Dinner    176
# Name: count, dtype: int64

# %%
arr = np.random.randint(40,50,50)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(df['total_bill'],color='r',marker='*' ,ms = 15,mfc='g',lw=1)
plt.title('line plot')
plt.xlabel('axis - x')
plt.ylabel('axis - y')
plt.show()

# %%
plt.scatter(df['total_bill'],df['tip'],color='r',marker='*')
plt.title('scatter plot',size=20,color='b')
plt.xlabel('totoal bill',size=20,color='b')
plt.ylabel('tips',size=20,color='b')
plt.show()

# %%
plt.bar(df['time'],df['total_bill'],ec='k',color = 'g')
plt.xlabel('time')
plt.ylabel('total bill')
plt.show()

# %%
plt.bar(df['day'],df['total_bill'])
plt.xlabel('time')
plt.ylabel('total bill')
plt.show()

# %%
plt.barh(df['day'],df['total_bill'])
plt.xlabel('time')
plt.ylabel('total bill')
plt.show()

# %%
bins = [0,30,50,80]
plt.hist(df['total_bill'],bins,ec='k')
plt.show()

# %%
plt.boxplot(df['total_bill'])
plt.show()

# %%
label = list(df['day'].value_counts().index)
value = list(df['day'].value_counts().values)

# %%
plt.pie(value,labels=label,explode=[0,0.3,0,0.2],autopct="%1.2f%%",shadow=True , wedgeprops={'ec':'k'})
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
sns.scatterplot(x = df['total_bill'],y = df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.barplot(x= df['day'],y=df['total_bill'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(df['tip'],kind='kde' , fill = True)

# %%
sns.displot(np.random.randint(100,size=(200)),kind='kde',fill=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip' ,data=df,hue='time',col='time')
# plt.title('scatterplot')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip' ,data=df,hue='time',col='time',style='sex')
# plt.title('scatterplot')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip' ,kind='line' ,data=df,hue='time',col='time')
# plt.title('scatterplot')
plt.show()

# %%
sns.countplot(x='day', data=df,ec='k')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.catplot(x='time',y='total_bill',kind='bar',ec='k',data=df,)

# %%
sns.catplot(x='time',y='total_bill',data=df)

# %%
sns.catplot(x='time',y='total_bill',kind='violin',data=df)

# %%
sns.catplot(x='time',y='total_bill',kind='boxen',data=df)

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip' ,kind='line',data=df)

# %%
sns.set(rc={'figure.figsize':(7,4)})
sns.relplot(x='total_bill',y='tip',data=df,hue='day',col='day')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',kind='line',data=df,hue='day',col='day')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df)

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar',hue='time')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar',hue='time',row='day')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='boxen')

# %%
sns.boxplot(x='total_bill',data=df,hue='day')
# Out:
# <Axes: xlabel='total_bill'>
